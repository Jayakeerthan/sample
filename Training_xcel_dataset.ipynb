# %%
from langchain.llms import Ollama

# %%
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm = Ollama(base_url='http://172.17.226.116:11434',
model="orca2:7b",temperature=0.5,
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()]))

# %%
#Added extra shortcuts and got output for a value
table="""
        Table: IT System Downtime Resolution Log
| Root Cause                                                                                                                                | Solution                                                                                                               | Key                          |
|-------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------|------------------------------|
| 1) Increase the seal air pressure by checking gauge in manifold (Units without Seal air pressure sensor) 
Increase the seal air pressure by checking the controller display (Units with Seal air pressure sensor) | 1) Increase the seal air pressure by checking gauge in manifold (Units without Seal air pressure sensor) Increase the seal air pressure by checking the controller display | [Seal air pressure low]     |
| 2) Check and open the ball valve partially and set seal air pressure                                                                       |                                                                                                                       | [Seal air pressure low]     |
| 3) Replace the seal air pressure MOS filter element or MOS assembly                                                                       |                                                                                                                       | [Seal air pressure low]     |
| 4) Replace the DCV assembly and maintain the water level                                                                                   |                                                                                                                      | [Seal air pressure low]     |
                                                                                                                                        | Replace the discharge check valve assembly                                                                           | [Discharge check valve (DCV)|
                                                                                                                                                 | Discharge check valve (DCV)|"""


llm("""You are a Ai for Elgi Equiments Limitted so introduce yourself as "chat assistant for Elgi",
 
    Learn the table thoroughly : {table}
    Based on the given table answer to the user's questions\
    ```I have root cause "Replace the DCV assembly and maintain the water level " give me  key for this cause based on the above table```
    """)
# Out:
# Hello, I am a chat assistant for Elgi. I can help you find the key for the root cause "Replace the DCV assembly and maintain the water level" based on the table below:
#
# | Root Cause | Key |
# |-----------|-----|
# | Replace the DCV assembly | K1 |
# | Maintain the water level | K2 |
# | Insufficient pressure in the pump | K3 |
# | Leakage in the hose | K4 |
# | Low voltage or power failure | K5 |
# | Worn out brushes and cylinders | K6 |
#
# To find the key for your root cause, you need to match the description of your problem with the possible causes from the table. For example, if your problem is that the water pressure is low, you can look for the cause that has the same symptom. In this case, the cause that matches your problem is K3, which says "insufficient pressure in the pump". Therefore, the key for your root cause is K3.
#
# I hope this helps. Do you have any other questions?
# 'Hello, I am a chat assistant for Elgi. I can help you find the key for the root cause "Replace the DCV assembly and maintain the water level" based on the table below:\n\n| Root Cause | Key |\n|-----------|-----|\n| Replace the DCV assembly | K1 |\n| Maintain the water level | K2 |\n| Insufficient pressure in the pump | K3 |\n| Leakage in the hose | K4 |\n| Low voltage or power failure | K5 |\n| Worn out brushes and cylinders | K6 |\n\nTo find the key for your root cause, you need to match the description of your problem with the possible causes from the table. For example, if your problem is that the water pressure is low, you can look for the cause that has the same symptom. In this case, the cause that matches your problem is K3, which says "insufficient pressure in the pump". Therefore, the key for your root cause is K3.\n\nI hope this helps. Do you have any other questions?'

# %% [markdown]
# Approach: feeding the table direclty into model (test-1)

# %%
from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

llm = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca2:7b",
    temperature=0.1,top_k=40,top_p=0.9,repeat_penalty=1.1,repeat_last_n=64,tfs_z=1,
)

# Added extra shortcuts and got output for a value
table = """
symptom				            |confirmation				            |Check Point				            |Procedure 					                |
-----------------------------------------------------------------------------------------------------------------------------------------------------------------	
 Water leakage from vent        | Continuous or intermittent water 	    | is the water coming out 		        | Check physically for the water leakage  	|
holes While running		        |leakage during running			        |from airend side vent holes            |from airend discharge vent holes.		    |
-----------------------------------------------------------------------------------------------------------------------------------------------------------------
 Water leakage from vent 	    | Water leakage observed after shutdown | Check the Discharge check 		    | Check physically for the water leakage 	|
hole after unit shutdown	    |					                    |valve condition and its function	    |from airend discharge vent holes		    |
-----------------------------------------------------------------------------------------------------------------------------------------------------------------
 Water level high in tank	    | No water from constant drain valve 	| Check  for the blockage in the 	    | Remove the strainer/orifice and check 	|
				                |(Units with CDV drain system) No water |constant drain system strainer/orifice	|for any dust contaminationor blockage 		|
				                |from sump ADV drain(Units with sump ADV|					                    |						                    |
-----------------------------------------------------------------------------------------------------------------------------------------------------------------                                                                
        """

response = llm(f"""
    You are an AI chat assistant for Elgi Equipments Limited.\
        Answer to the user's question in formatted manner.\

    Learn the table thoroughly: {table}
    Based on the given table, answer the user's question:
    Water leakage is found out in the compressor - what to do ?"
""")
print(response)
# Out:
# Possible answer:
#
# To answer the user's question, we need to find the symptom and the confirmation from the table that match the water leakage in the compressor. The symptom is water leakage from vent holes while running, and the confirmation is continuous or intermittent water coming out from airend side vent holes. Therefore, we can follow the procedure for this check point as given in the table:
#
# - Check physically for the water leakage from the airend side vent holes of the compressor. If there is any water leakage, it indicates a problem with the sealing or the valve of the vent holes.
# - If there is no water leakage from the airend side vent holes, check the discharge check valve and its function. The discharge check valve prevents the water from flowing back to the compressor from the discharge line. If the discharge check valve is not working properly, it can cause water leakage in the compressor.
# - If there is no water leakage from the airend side vent holes and the discharge check valve, then there might be a blockage or contamination in the strainer or orifice of the constant drain system. The constant drain system drains the excess oil from the compressor after each cycle. If it is blocked or dirty, it can cause water leakage in the compressor.
# - To check for any dust contamination or blockage in the constant drain system strainer/orifice, remove it and inspect it for any debris or damage. If there is any, clean it or replace it with a new one. If there is no dust contamination or blockage, then the water leakage might be coming from the sump airend discharge vent holes.
# - To check for any water leakage from the sump airend discharge vent holes, remove them and inspect them for any damage or corrosion. If there is any, repair or replace them with new ones. If there is no water leakage, then the compressor might be leaking oil instead of water.
# - To check for any oil leakage from the compressor, use an infrared camera or a dye test kit to locate the source of the oil leakage. Then, follow the same procedure as above to fix the problem.
#
# ### Final answer: The possible steps to do when water leakage is found out in the compressor are to check physically for the water leakage from the airend side vent holes, check the discharge check valve and its function, check for any blockage or contamination in the constant drain system strainer/orifice, remove and inspect them for any debris or damage, check for any water leakage from the sump airend discharge vent holes, remove and inspect them for any damage or corrosion, use an infrared camera or a dye test kit to locate the source of the oil leakage, and follow the same procedure as above to fix the problem.

# %% [markdown]
# Approach: Loading the xcel file directly into model

# %%
from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
import pandas as pd 

# Load your Excel sheet into a pandas DataFrame
excel_file_path = 'D:\problems.xlsx'
df = pd.read_excel(excel_file_path)

# Assuming you have a column named 'symptom' in your Excel sheet
table = df.to_markdown(index=False)

llm = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca2:7b",
    temperature=0, top_k=40, top_p=0.9, repeat_penalty=1.1, repeat_last_n=64, tfs_z=1,
)

# Answer user's question based on the table
response = llm(f"""
    You are an AI chat assistant for Elgi Equipments Limited.\
    Answer to the user's question in a formatted manner.\

    Learn the table thoroughly:\n{table}
    Based on the given table, answer the user's question:
    "I have a symptom of 'water level high in  tank,' what is the corresponding confirmation?"
""")
print(response)
# Out:
# The corresponding confirmation for the symptom 'water level high in tank' is not explicitly mentioned in the given table. However, based on the information provided and the context of other symptoms, it can be inferred that the issue might be related to a malfunctioning pressure transmitter or no feedback from the pressure transmitter to the VFD.

# %% [markdown]
# loading xcel file-test 2

# %%
from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.embeddings import OllamaEmbeddings
import pandas as pd 

# Load your Excel sheet into a pandas DataFrame
excel_file_path = 'D:\problems.xlsx'
df = pd.read_excel(excel_file_path)

# Assuming you have a column named 'symptom' in your Excel sheet
table = df.to_markdown(index=False)

llm = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca-mini:3b",
    temperature=0.2, top_k=40, top_p=0.9, repeat_penalty=1.1, repeat_last_n=64, tfs_z=1,
)

# Answer user's question based on the table
response = llm(f"""
    You are an AI chat assistant for Elgi Equipments Limited.\
    Answer to the user's question in a formatted manner.\

    Learn the table thoroughly:\n```{table}```
    
    
    "how many catogeries of symptons are there in the table"
""")
print(response)
# Out:
# I'm sorry, but I cannot provide you with a response as I am an AI language model and do not have the ability to understand human language.

# %%
from langchain.llms import ollama
from langchain.indexes import VectorstoreIndexCreator
from langchain.chains import RetrievalQA
import os
from langchain.embeddings import OllamaEmbeddings

# %%
loader = 'D:\problems.xlsx'
index_creator = VectorstoreIndexCreator()
docsearch = index_creator.from_loaders([loader])
ollama.api_key=os.getenv("ollama_api_key")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[55], line 2
#       1 loader = 'D:\problems.xlsx'
# ----> 2 index_creator = VectorstoreIndexCreator()
#       3 docsearch = index_creator.from_loaders([loader])
#       4 ollama.api_key=os.getenv("ollama_api_key")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\main.py:339, in BaseModel.__init__(__pydantic_self__, **data)
#     333 """
#     334 Create a new model by parsing and validating input data from keyword arguments.
#     335
#     336 Raises ValidationError if the input data cannot be parsed to form a valid model.
#     337 """
#     338 # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
#     341     raise validation_error
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\main.py:1066, in validate_model(model, input_data, cls)
#    1063     errors.append(ErrorWrapper(MissingError(), loc=field.alias))
#    1064     continue
# -> 1066 value = field.get_default()
#    1068 if not config.validate_all and not field.validate_always:
#    1069     values[name] = value
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\fields.py:439, in ModelField.get_default(self)
#     438 def get_default(self) -> Any:
# --> 439     return smart_deepcopy(self.default) if self.default_factory is None else self.default_factory()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for OpenAIEmbeddings
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass  `openai_api_key` as a named parameter. (type=value_error)

# %%
ollama.api_key=

# %%
from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.document_loaders import UnstructuredExcelLoader
import pandas as pd 

# Load your Excel sheet into a pandas DataFrame
loader = UnstructuredExcelLoader("D:\problems.xlsx", mode="elements")
docs = loader.load()
print(docs[0])
# Assuming you have a column named 'symptom' in your Excel sheet


llm = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca-mini:3b",
    temperature=0.2, top_k=40, top_p=0.9, repeat_penalty=1.1, repeat_last_n=64, tfs_z=1,
)

# Answer user's question based on the table
response = llm(f"""
    You are an AI chat assistant for Elgi Equipments Limited.\
    Answer to the user's question in a formatted manner.\

    Learn the table thoroughly:\n```{docs}```
    
    
    "how many catogeries of symptons are there in the table"
""")
print(response)
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     WRONG_VERSION_NUMBER] wrong version number
# [nltk_data]     (_ssl.c:1006)>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[60], line 9
#       7 # Load your Excel sheet into a pandas DataFrame
#       8 loader = UnstructuredExcelLoader("D:\problems.xlsx", mode="elements")
# ----> 9 docs = loader.load()
#      10 print(docs[0])
#      11 # Assuming you have a column named 'symptom' in your Excel sheet
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_community\document_loaders\unstructured.py:87, in UnstructuredBaseLoader.load(self)
#      85 def load(self) -> List[Document]:
#      86     """Load file."""
# ---> 87     elements = self._get_elements()
#      88     self._post_process_elements(elements)
#      89     if self.mode == "elements":
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_community\document_loaders\excel.py:46, in UnstructuredExcelLoader._get_elements(self)
#      43 def _get_elements(self) -> List:
#      44     from unstructured.partition.xlsx import partition_xlsx
# ---> 46     return partition_xlsx(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\documents\elements.py:514, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     512 @functools.wraps(func)
#     513 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 514     elements = func(*args, **kwargs)
#     515     sig = inspect.signature(func)
#     516     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\file_utils\filetype.py:591, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     589 @functools.wraps(func)
#     590 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 591     elements = func(*args, **kwargs)
#     592     sig = inspect.signature(func)
#     593     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\file_utils\filetype.py:546, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     544 @functools.wraps(func)
#     545 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 546     elements = func(*args, **kwargs)
#     547     sig = inspect.signature(func)
#     548     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\chunking\__init__.py:52, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      50 @functools.wraps(func)
#      51 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# ---> 52     elements = func(*args, **kwargs)
#      53     sig = inspect.signature(func)
#      54     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\partition\xlsx.py:158, in partition_xlsx(filename, file, metadata_filename, include_metadata, infer_table_structure, languages, detect_language_per_element, metadata_last_modified, include_header, find_subtable, **kwargs)
#     156 if front_non_consecutive is not None:
#     157     for content in single_non_empty_row_contents[: front_non_consecutive + 1]:
# --> 158         element = _check_content_element_type(str(content))
#     159         element.metadata = metadata
#     160         elements.append(element)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\partition\xlsx.py:366, in _check_content_element_type(text)
#     362 elif is_possible_numbered_list(text):
#     363     return ListItem(
#     364         text=text,
#     365     )
# --> 366 elif is_possible_narrative_text(text):
#     367     return NarrativeText(
#     368         text=text,
#     369     )
#     370 elif is_possible_title(text):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\partition\text_type.py:77, in is_possible_narrative_text(text, cap_threshold, non_alpha_threshold, languages, language_checks)
#      72 # NOTE(robinson): it gets read in from the environment as a string so we need to
#      73 # cast it to a float
#      74 cap_threshold = float(
#      75     os.environ.get("UNSTRUCTURED_NARRATIVE_TEXT_CAP_THRESHOLD", cap_threshold),
#      76 )
# ---> 77 if exceeds_cap_ratio(text, threshold=cap_threshold):
#      78     trace_logger.detail(f"Not narrative. Text exceeds cap ratio {cap_threshold}:\n\n{text}")  # type: ignore # noqa: E501
#      79     return False
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\partition\text_type.py:273, in exceeds_cap_ratio(text, threshold)
#     260 """Checks the title ratio in a section of text. If a sufficient proportion of the words
#     261 are capitalized, that can be indicated on non-narrative text (i.e. "1A. Risk Factors").
#     262
#    (...)
#     269     the function returns True
#     270 """
#     271 # NOTE(robinson) - Currently limiting this to only sections of text with one sentence.
#     272 # The assumption is that sections with multiple sentences are not titles.
# --> 273 if sentence_count(text, 3) > 1:
#     274     return False
#     276 if text.isupper():
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\partition\text_type.py:222, in sentence_count(text, min_length)
#     211 def sentence_count(text: str, min_length: Optional[int] = None) -> int:
#     212     """Checks the sentence count for a section of text. Titles should not be more than one
#     213     sentence.
#     214
#    (...)
#     220         The min number of words a section needs to be for it to be considered a sentence.
#     221     """
# --> 222     sentences = sent_tokenize(text)
#     223     count = 0
#     224     for sentence in sentences:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\unstructured\nlp\tokenize.py:30, in sent_tokenize(text)
#      28 """A wrapper around the NLTK sentence tokenizer with LRU caching enabled."""
#      29 _download_nltk_package_if_not_present(package_category="tokenizers", package_name="punkt")
# ---> 30 return _sent_tokenize(text)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/english.pickle
#
#   Searched in:
#     - 'C:\\Users\\intern_dx23/nltk_data'
#     - 'c:\\Users\\intern_dx23\\AppData\\Local\\Programs\\Python\\Python311\\nltk_data'
#     - 'c:\\Users\\intern_dx23\\AppData\\Local\\Programs\\Python\\Python311\\share\\nltk_data'
#     - 'c:\\Users\\intern_dx23\\AppData\\Local\\Programs\\Python\\Python311\\lib\\nltk_data'
#     - 'C:\\Users\\intern_dx23\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************

# %%
print(docs[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(docs[0])
#
# NameError: name 'docs' is not defined

# %%
import pandas as pd

df = pd.read_excel('D:\problems.xlsx')
df.head(10)
# Out:
#   Group  Solution Id Language  Complaint Id  \
# 0    AB          679  English            73
# 1    AB          680  English            74
# 2    AB          681  English            74
# 3    AB          682  English            74
# 4    AB          683  English            74
# 5    AB          684  English            75
# 6    AB          685  English            75
# 7    AB          686  English            75
# 8    AB          687  English            76
# 9    AB          688  English            76
#
#                                             Sysmtom  \
# 0     Water leakage from vent holes (While running)
# 1  Water leakage from vent hole after unit shutdown
# 2  Water leakage from vent hole after unit shutdown
# 3  Water leakage from vent hole after unit shutdown
# 4  Water leakage from vent hole after unit shutdown
# 5                          Water level high in tank
# 6                          Water level high in tank
# 7                          Water level high in tank
# 8     High differential pressure water filter alarm
# 9     High differential pressure water filter alarm
#
#                                         Confirmation  \
# 0  Continuous or intermittent water leakage durin...
# 1              Water leakage observed after shutdown
# 2              Water leakage observed after shutdown
# 3              Water leakage observed after shutdown
# 4              Water leakage observed after shutdown
# 5  No water from constant drain valve (Units with...
# 6  No water from constant drain valve (Units with...
# 7  No water from constant drain valve (Units with...
# 8  Differential pressure is higher than the set p...
# 9  Differential pressure is higher than the set p...
#
#                                          Check Point  \
# 0  Is the water coming out from airend side vent ...
# 1  Check the Discharge check valve condition and ...
# 2  Check the Water stop valve condition and its f...
# 3  Check the discharge line connection to service...
# 4  Check the blow down valve condition and its fu...
# 5  Check for the blockage in the constant drain s...
# 6  Check the sump Auto drain valve (ADV) conditio...
# 7              Check the water level sensor function
# 8  Check if the warning goes OFF when reset butto...
# 9  Is the differential pressure setting value dis...
#
#                                            Procedure  \
# 0  Check physically for the water leakage from ai...
# 1  1)Switch off the machine in normal stop mode a...
# 2  Dismantle the Water stop valve from the system...
# 3  Check whether the compressor discharge line co...
# 4  Dismantle the blow down valve and check condit...
# 5  Remove the strainer/orifice and check for any ...
# 6   Remove and check the function of ADV or blockage
# 7  Remove and check the water level sensor float ...
# 8                       Check the controller display
# 9  Check the Water filter differential pressure s...
#
#                                           Root Cause  \
# 0  1)Seal air pressure is low 2)Seal air pressure...
# 1  Discharge check valve Spring broken or Imprope...
# 2  1)Malfunctioning of solenoid coil 2)Diaphragm ...
# 3  1) Condesate water entered into the compressor...
# 4  Blow down valve piston stuck/internal parts da...
# 5  Foreign particle/Dust/Impurities entry in the ...
# 6  1) Solenoid valve failed internally 2) Foreign...
# 7                         Water level sensor failure
# 8  1) Controller set value disturbed 2) DP Pressu...
# 9  1) Controller set value disturbed 2) DP Pressu...
#
#                                             Solution  \
# 0  1)Increase the seal air pressure by checking g...
# 1         Replace the discharge check valve assembly
# 2  1 & 2) Replace the Water stop valve assembly 3...
# 3  1) Ensure the compressor outlet pipe connected...
# 4               Replace the blow down valve assembly
# 5  1)Clean/Replace the strainer and orifice assem...
# 6                               Replace the sump ADV
# 7                     Replace the water level sensor
# 8  1) Press the reset button in controller and mo...
# 9  1)Press the reset button in controller and mon...
#
#                                          Key  is_active
# 0                      Seal air pressure low          0
# 1                Discharge check valve (DCV)          0
# 2                           Water stop valve          0
# 3                                        NaN          0
# 4                      Blow down valve (BDV)          0
# 5                                   Strainer          0
# 6        Auto drain valve ADV Solenoid valve          0
# 7                         Water level sensor          0
# 8                            Pressure switch          0
# 9  Water filter differential pressure switch          0

# %%
from langchain_experimental.agents import create_csv_agent
from langchain.llms import Ollama

# %%
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
agent = create_csv_agent(Ollama(base_url='http://172.17.226.116:11434',
model="orca2:7b",temperature=0.8), 
                         'D:\problems.csv', 
                         verbose=True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 agent = create_csv_agent(Ollama(base_url='http://172.17.226.116:11434',
#       2 model="orca2:7b",temperature=0.8),
#       3                          'D:\problems.csv',
#       4                          verbose=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_experimental\agents\agent_toolkits\csv\base.py:28, in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      26 _kwargs = pandas_kwargs or {}
#      27 if isinstance(path, (str, IOBase)):
# ---> 28     df = pd.read_csv(path, **_kwargs)
#      29 elif isinstance(path, list):
#      30     df = []
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:668, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 104772: invalid continuation byte

# %%
import pandas as pd
from langchain_experimental.agents import create_csv_agent
from langchain.llms import Ollama

# Specify the encoding you expect for the CSV file
csv_encoding = 'utf-8'  # You may need to adjust this based on the actual encoding

# Specify the path to the CSV file
csv_file_path = 'D:\problems.csv'

# Create an Ollama instance
ollama_instance = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca-mini:3b",
    temperature=0.8
)

try:
    # Attempt to read the CSV file with the specified encoding
    df = pd.read_csv(csv_file_path, encoding=csv_encoding)

    # Create the CSV agent using Ollama and the DataFrame
    agent = create_csv_agent(ollama_instance, df, verbose=True)

except UnicodeDecodeError:
    # Handle the UnicodeDecodeError by trying a different encoding
    alternative_encoding = 'latin-1'  # You may also try 'cp1252' or other encodings
    df = pd.read_csv(csv_file_path, encoding=alternative_encoding)
    agent = create_csv_agent(ollama_instance, df, verbose=True)

# Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1119, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1271, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1284, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1532, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 20
#      18 try:
#      19     # Attempt to read the CSV file with the specified encoding
# ---> 20     df = pd.read_csv(csv_file_path, encoding=csv_encoding)
#      22     # Create the CSV agent using Ollama and the DataFrame
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     233 if self.low_memory:
# --> 234     chunks = self._reader.read_low_memory(nrows)
#     235     # destructive to chunks
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:920, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:1065, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File parsers.pyx:1126, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1271, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1284, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1532, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 29
#      27     alternative_encoding = 'latin-1'  # You may also try 'cp1252' or other encodings
#      28     df = pd.read_csv(csv_file_path, encoding=alternative_encoding)
# ---> 29     agent = create_csv_agent(ollama_instance, df, verbose=True)
#      31 # Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_experimental\agents\agent_toolkits\csv\base.py:36, in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      34         df.append(pd.read_csv(item, **_kwargs))
#      35 else:
# ---> 36     raise ValueError(f"Expected str, list, or file-like object, got {type(path)}")
#      37 return create_pandas_dataframe_agent(llm, df, **kwargs)
#
# ValueError: Expected str, list, or file-like object, got <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
from langchain_experimental.agents import create_csv_agent
from langchain.llms import Ollama

# Specify the encoding you expect for the CSV file
csv_encoding = 'utf-8'  # You may need to adjust this based on the actual encoding

# Specify the path to the CSV file
csv_file_path = 'D:\\problems.csv'

# Create an Ollama instance
ollama_instance = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca-mini:3b",
    temperature=0.8
)

try:
    # Attempt to read the CSV file with the specified encoding
    df = pd.read_csv(csv_file_path, encoding=csv_encoding)

    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV file path
    agent = create_csv_agent(ollama_instance, csv_file_path, verbose=True)

except UnicodeDecodeError:
    # Handle the UnicodeDecodeError by trying a different encoding
    alternative_encoding = 'latin-1'  # You may also try 'cp1252' or other encodings
    df = pd.read_csv(csv_file_path, encoding=alternative_encoding)
    
    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV file path
    agent = create_csv_agent(ollama_instance, csv_file_path, verbose=True)

# Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
# Out:
#   Group  Solution Id Language  Complaint Id  \
# 0    AB          679  English            73
# 1    AB          680  English            74
# 2    AB          681  English            74
# 3    AB          682  English            74
# 4    AB          683  English            74
#
#                                             Sysmtom  \
# 0     Water leakage from vent holes (While running)
# 1  Water leakage from vent hole after unit shutdown
# 2  Water leakage from vent hole after unit shutdown
# 3  Water leakage from vent hole after unit shutdown
# 4  Water leakage from vent hole after unit shutdown
#
#                                         Confirmation  \
# 0  Continuous or intermittent water leakage durin...
# 1              Water leakage observed after shutdown
# 2              Water leakage observed after shutdown
# 3              Water leakage observed after shutdown
# 4              Water leakage observed after shutdown
#
#                                          Check Point  \
# 0  Is the water coming out from airend side vent ...
# 1  Check the Discharge check valve condition and ...
# 2  Check the Water stop valve condition and its f...
# 3  Check the discharge line connection to service...
# 4  Check the blow down valve condition and its fu...
#
#                                            Procedure  \
# 0  Check physically for the water leakage from ai...
# 1  1)Switch off the machine in normal stop mode a...
# 2  Dismantle the Water stop valve from the system...
# 3  Check whether the compressor discharge line co...
# 4  Dismantle the blow down valve and check condit...
#
#                                           Root Cause  \
# 0  1)Seal air pressure is low 2)Seal air pressure...
# 1  Discharge check valve Spring broken or Imprope...
# 2  1)Malfunctioning of solenoid coil 2)Diaphragm ...
# 3  1) Condesate water entered into the compressor...
# 4  Blow down valve piston stuck/internal parts da...
#
#                                             Solution  \
# 0  1)Increase the seal air pressure by checking g...
# 1         Replace the discharge check valve assembly
# 2  1 & 2) Replace the Water stop valve assembly 3...
# 3  1) Ensure the compressor outlet pipe connected...
# 4               Replace the blow down valve assembly
#
#                            Key  is_active
# 0        Seal air pressure low          0
# 1  Discharge check valve (DCV)          0
# 2             Water stop valve          0
# 3                          NaN          0
# 4        Blow down valve (BDV)          0
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1119, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1271, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1284, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1532, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[12], line 20
#      18 try:
#      19     # Attempt to read the CSV file with the specified encoding
# ---> 20     df = pd.read_csv(csv_file_path, encoding=csv_encoding)
#      22     # Print or process the DataFrame as needed
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     233 if self.low_memory:
# --> 234     chunks = self._reader.read_low_memory(nrows)
#     235     # destructive to chunks
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:920, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:1065, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File parsers.pyx:1126, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1271, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1284, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1532, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[12], line 37
#      34     print(df.head())
#      36     # Create the CSV agent using Ollama and the CSV file path
# ---> 37     agent = create_csv_agent(ollama_instance, csv_file_path, verbose=True)
#      39 # Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_experimental\agents\agent_toolkits\csv\base.py:28, in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      26 _kwargs = pandas_kwargs or {}
#      27 if isinstance(path, (str, IOBase)):
# ---> 28     df = pd.read_csv(path, **_kwargs)
#      29 elif isinstance(path, list):
#      30     df = []
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:668, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 104772: invalid continuation byte

# %%
import pandas as pd
import chardet
from langchain_experimental.agents import create_csv_agent
from langchain.llms import Ollama

# Specify the path to the CSV file
csv_file_path = 'D:\\problems.csv'

# Create an Ollama instance
ollama_instance = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca2:7b",
    temperature=0.8
)

def read_csv_with_encoding(file_path, encoding):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return pd.read_csv(file_path, encoding=result['encoding'])

try:
    # Attempt to read the CSV file with the specified encoding
    df = read_csv_with_encoding(csv_file_path, 'utf-8')

    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV file path
    agent = create_csv_agent(ollama_instance, csv_file_path, verbose=True)

except UnicodeDecodeError:
    # Handle the UnicodeDecodeError by trying a different encoding
    df = read_csv_with_encoding(csv_file_path, 'latin-1')

    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV file path
    agent = create_csv_agent(ollama_instance, csv_file_path, verbose=True)

# Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
# Out:
#   Group  Solution Id Language  Complaint Id  \
# 0    AB          679  English            73
# 1    AB          680  English            74
# 2    AB          681  English            74
# 3    AB          682  English            74
# 4    AB          683  English            74
#
#                                             Sysmtom  \
# 0     Water leakage from vent holes (While running)
# 1  Water leakage from vent hole after unit shutdown
# 2  Water leakage from vent hole after unit shutdown
# 3  Water leakage from vent hole after unit shutdown
# 4  Water leakage from vent hole after unit shutdown
#
#                                         Confirmation  \
# 0  Continuous or intermittent water leakage durin...
# 1              Water leakage observed after shutdown
# 2              Water leakage observed after shutdown
# 3              Water leakage observed after shutdown
# 4              Water leakage observed after shutdown
#
#                                          Check Point  \
# 0  Is the water coming out from airend side vent ...
# 1  Check the Discharge check valve condition and ...
# 2  Check the Water stop valve condition and its f...
# 3  Check the discharge line connection to service...
# 4  Check the blow down valve condition and its fu...
#
#                                            Procedure  \
# 0  Check physically for the water leakage from ai...
# 1  1)Switch off the machine in normal stop mode a...
# 2  Dismantle the Water stop valve from the system...
# 3  Check whether the compressor discharge line co...
# 4  Dismantle the blow down valve and check condit...
#
#                                           Root Cause  \
# 0  1)Seal air pressure is low 2)Seal air pressure...
# 1  Discharge check valve Spring broken or Imprope...
# 2  1)Malfunctioning of solenoid coil 2)Diaphragm ...
# 3  1) Condesate water entered into the compressor...
# 4  Blow down valve piston stuck/internal parts da...
#
#                                             Solution  \
# 0  1)Increase the seal air pressure by checking g...
# 1         Replace the discharge check valve assembly
# 2  1 & 2) Replace the Water stop valve assembly 3...
# 3  1) Ensure the compressor outlet pipe connected...
# 4               Replace the blow down valve assembly
#
#                            Key  is_active
# 0        Seal air pressure low          0
# 1  Discharge check valve (DCV)          0
# 2             Water stop valve          0
# 3                          NaN          0
# 4        Blow down valve (BDV)          0
#   Group  Solution Id Language  Complaint Id  \
# 0    AB          679  English            73
# 1    AB          680  English            74
# 2    AB          681  English            74
# 3    AB          682  English            74
# 4    AB          683  English            74
#
#                                             Sysmtom  \
# 0     Water leakage from vent holes (While running)
# 1  Water leakage from vent hole after unit shutdown
# 2  Water leakage from vent hole after unit shutdown
# 3  Water leakage from vent hole after unit shutdown
# 4  Water leakage from vent hole after unit shutdown
#
#                                         Confirmation  \
# 0  Continuous or intermittent water leakage durin...
# 1              Water leakage observed after shutdown
# 2              Water leakage observed after shutdown
# 3              Water leakage observed after shutdown
# 4              Water leakage observed after shutdown
#
#                                          Check Point  \
# 0  Is the water coming out from airend side vent ...
# 1  Check the Discharge check valve condition and ...
# 2  Check the Water stop valve condition and its f...
# 3  Check the discharge line connection to service...
# 4  Check the blow down valve condition and its fu...
#
#                                            Procedure  \
# 0  Check physically for the water leakage from ai...
# 1  1)Switch off the machine in normal stop mode a...
# 2  Dismantle the Water stop valve from the system...
# 3  Check whether the compressor discharge line co...
# 4  Dismantle the blow down valve and check condit...
#
#                                           Root Cause  \
# 0  1)Seal air pressure is low 2)Seal air pressure...
# 1  Discharge check valve Spring broken or Imprope...
# 2  1)Malfunctioning of solenoid coil 2)Diaphragm ...
# 3  1) Condesate water entered into the compressor...
# 4  Blow down valve piston stuck/internal parts da...
#
#                                             Solution  \
# 0  1)Increase the seal air pressure by checking g...
# 1         Replace the discharge check valve assembly
# 2  1 & 2) Replace the Water stop valve assembly 3...
# 3  1) Ensure the compressor outlet pipe connected...
# 4               Replace the blow down valve assembly
#
#                            Key  is_active
# 0        Seal air pressure low          0
# 1  Discharge check valve (DCV)          0
# 2             Water stop valve          0
# 3                          NaN          0
# 4        Blow down valve (BDV)          0
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[13], line 29
#      28     # Create the CSV agent using Ollama and the CSV file path
# ---> 29     agent = create_csv_agent(ollama_instance, csv_file_path, verbose=True)
#      31 except UnicodeDecodeError:
#      32     # Handle the UnicodeDecodeError by trying a different encoding
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_experimental\agents\agent_toolkits\csv\base.py:28, in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      27 if isinstance(path, (str, IOBase)):
# ---> 28     df = pd.read_csv(path, **_kwargs)
#      29 elif isinstance(path, list):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:668, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 104772: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[13], line 39
#      36     print(df.head())
#      38     # Create the CSV agent using Ollama and the CSV file path
# ---> 39     agent = create_csv_agent(ollama_instance, csv_file_path, verbose=True)
#      41 # Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_experimental\agents\agent_toolkits\csv\base.py:28, in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      26 _kwargs = pandas_kwargs or {}
#      27 if isinstance(path, (str, IOBase)):
# ---> 28     df = pd.read_csv(path, **_kwargs)
#      29 elif isinstance(path, list):
#      30     df = []
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:668, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 104772: invalid continuation byte

# %%
import pandas as pd
import chardet
from langchain_experimental.agents import create_csv_agent
from langchain.llms import Ollama

# Specify the path to the CSV file
csv_file_path = 'D:\\problems.csv'

# Create an Ollama instance
ollama_instance = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca-mini:3b",
    temperature=0.8
)

def read_csv_with_encoding(file_path, encoding):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return pd.read_csv(file_path, encoding=encoding)

try:
    # Attempt to read the CSV file with the specified encoding
    df = read_csv_with_encoding(csv_file_path, 'utf-8')

    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV DataFrame
    agent = create_csv_agent(ollama_instance, df, verbose=True)

except UnicodeDecodeError:
    # Handle the UnicodeDecodeError by trying a different encoding
    alternative_encoding = 'latin-1'  # You may also try 'cp1252' or other encodings
    df = read_csv_with_encoding(csv_file_path, alternative_encoding)

    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV DataFrame
    agent = create_csv_agent(ollama_instance, df, verbose=True)

# Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
# Out:
#   Group  Solution Id Language  Complaint Id  \
# 0    AB          679  English            73
# 1    AB          680  English            74
# 2    AB          681  English            74
# 3    AB          682  English            74
# 4    AB          683  English            74
#
#                                             Sysmtom  \
# 0     Water leakage from vent holes (While running)
# 1  Water leakage from vent hole after unit shutdown
# 2  Water leakage from vent hole after unit shutdown
# 3  Water leakage from vent hole after unit shutdown
# 4  Water leakage from vent hole after unit shutdown
#
#                                         Confirmation  \
# 0  Continuous or intermittent water leakage durin...
# 1              Water leakage observed after shutdown
# 2              Water leakage observed after shutdown
# 3              Water leakage observed after shutdown
# 4              Water leakage observed after shutdown
#
#                                          Check Point  \
# 0  Is the water coming out from airend side vent ...
# 1  Check the Discharge check valve condition and ...
# 2  Check the Water stop valve condition and its f...
# 3  Check the discharge line connection to service...
# 4  Check the blow down valve condition and its fu...
#
#                                            Procedure  \
# 0  Check physically for the water leakage from ai...
# 1  1)Switch off the machine in normal stop mode a...
# 2  Dismantle the Water stop valve from the system...
# 3  Check whether the compressor discharge line co...
# 4  Dismantle the blow down valve and check condit...
#
#                                           Root Cause  \
# 0  1)Seal air pressure is low 2)Seal air pressure...
# 1  Discharge check valve Spring broken or Imprope...
# 2  1)Malfunctioning of solenoid coil 2)Diaphragm ...
# 3  1) Condesate water entered into the compressor...
# 4  Blow down valve piston stuck/internal parts da...
#
#                                             Solution  \
# 0  1)Increase the seal air pressure by checking g...
# 1         Replace the discharge check valve assembly
# 2  1 & 2) Replace the Water stop valve assembly 3...
# 3  1) Ensure the compressor outlet pipe connected...
# 4               Replace the blow down valve assembly
#
#                            Key  is_active
# 0        Seal air pressure low          0
# 1  Discharge check valve (DCV)          0
# 2             Water stop valve          0
# 3                          NaN          0
# 4        Blow down valve (BDV)          0
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1119, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1271, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1284, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1532, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 23
#      21 try:
#      22     # Attempt to read the CSV file with the specified encoding
# ---> 23     df = read_csv_with_encoding(csv_file_path, 'utf-8')
#      25     # Print or process the DataFrame as needed
#
# Cell In[14], line 19, in read_csv_with_encoding(file_path, encoding)
#      18     result = chardet.detect(f.read())
# ---> 19 return pd.read_csv(file_path, encoding=encoding)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     233 if self.low_memory:
# --> 234     chunks = self._reader.read_low_memory(nrows)
#     235     # destructive to chunks
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:920, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:1065, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File parsers.pyx:1126, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1271, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1284, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1532, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 40
#      37     print(df.head())
#      39     # Create the CSV agent using Ollama and the CSV DataFrame
# ---> 40     agent = create_csv_agent(ollama_instance, df, verbose=True)
#      42 # Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_experimental\agents\agent_toolkits\csv\base.py:36, in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      34         df.append(pd.read_csv(item, **_kwargs))
#      35 else:
# ---> 36     raise ValueError(f"Expected str, list, or file-like object, got {type(path)}")
#      37 return create_pandas_dataframe_agent(llm, df, **kwargs)
#
# ValueError: Expected str, list, or file-like object, got <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
from langchain_experimental.agents import create_csv_agent
from langchain.llms import Ollama
import tempfile

# Specify the path to the CSV file
csv_file_path = 'D:\\problems.csv'

# Create an Ollama instance
ollama_instance = Ollama(
    base_url='http://172.17.226.116:11434',
    model="orca-mini:3b",
    temperature=0.8
)

def create_csv_agent_modified(llm, data, pandas_kwargs=None, **kwargs):
    if isinstance(data, str):  # Check if 'data' is a file path
        df = pd.read_csv(data, **(pandas_kwargs or {}))
    elif isinstance(data, pd.DataFrame):  # Check if 'data' is a DataFrame
        df = data
    else:
        raise ValueError("Expected str (file path) or DataFrame, got {type(data)}")

    return create_csv_agent(llm, df, pandas_kwargs, **kwargs)

try:
    # Attempt to read the CSV file with the specified encoding
    df = pd.read_csv(csv_file_path, encoding='utf-8')

    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV DataFrame
    agent = create_csv_agent_modified(ollama_instance, df, verbose=True)

except UnicodeDecodeError:
    # Handle the UnicodeDecodeError by trying a different encoding
    alternative_encoding = 'latin-1'  # You may also try 'cp1252' or other encodings
    df = pd.read_csv(csv_file_path, encoding=alternative_encoding)

    # Print or process the DataFrame as needed
    print(df.head())

    # Create the CSV agent using Ollama and the CSV DataFrame
    agent = create_csv_agent_modified(ollama_instance, df, verbose=True)

# Now 'agent' is created successfully, and 'df' contains the DataFrame from the CSV

# %% [markdown]
# Converted the csv contents in python dictionaries

# %%
import pandas as pd
from langchain_experimental.agents import create_csv_agent
from langchain.llms import Ollama
import tempfile

from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler                                  


# Create an Ollama instance


llm = Ollama(base_url='http://172.17.226.116:11434',
model="orca2:7b",temperature=0.8,top_k=40,top_p=0.9,repeat_penalty=1.1,repeat_last_n=64,tfs_z=1,
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()]))

# Assume 'df' is your DataFrame
df = pd.DataFrame(data = [
    {
        "Group": "AB",
        "Solution Id": 679,
        "Language": "English",
        "Complaint Id": 73,
        "Sysmtom": "Water leakage from vent holes (While running)",
        "Confirmation": "Continuous or intermittent water leakage during running",
        "Check Point": "Is the water coming out from airend side vent holes",
        "Procedure": "Check physically for the water leakage from airend discharge vent holes",
        "Root Cause": "1)Seal air pressure is low 2)Seal air pressure ball valve kept in close position 3)Seal air pressure MOS filter element choked 4)Defect in the discharge check valve",
        "Solution": "1)Increase the seal air pressure by checking gauge in manifold (Units without Seal air pressure sensor) Increase the seal air pressure by checking the controller display (Units with Seal air pressure sensor) 2)Check and open the ball valve partially and set seal air pressure 3)Replace the seal air pressure MOS filter element or MOS assembly 4)Replace the DCV assembly and maintain the water level",
        "Key": "Seal air pressure low",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 680,
        "Language": "English",
        "Complaint Id": 74,
        "Sysmtom": "Water leakage from vent hole after unit shutdown",
        "Confirmation": "Water leakage observed after shutdown",
        "Check Point": "Check the Discharge check valve condition and its function",
        "Procedure": "1)Switch off the machine in normal stop mode and observe water throw from airend vent holes 2)Dismantle discharge check valve from the system and visually check the condition of spring and plunger",
        "Root Cause": "Discharge check valve Spring broken or Improper seating of plunger",
        "Solution": "Replace the discharge check valve assembly",
        "Key": "Discharge check valve (DCV)",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 681,
        "Language": "English",
        "Complaint Id": 74,
        "Sysmtom": "Water leakage from vent hole after unit shutdown",
        "Confirmation": "Water leakage observed after shutdown",
        "Check Point": "Check the Water stop valve condition and its function",
        "Procedure": "Dismantle the Water stop valve from the system and check for dust accumulation and diaphragm seating",
        "Root Cause": "1)Malfunctioning of solenoid coil 2)Diaphragm condition eroded/punctured 3) Accumulation of dust at diaphragm seat",
        "Solution": "1 & 2) Replace the Water stop valve assembly 3) Clean the Water stop valve assembly",
        "Key": "Water stop valve",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 682,
        "Language": "English",
        "Complaint Id": 74,
        "Sysmtom": "Water leakage from vent hole after unit shutdown",
        "Confirmation": "Water leakage observed after shutdown",
        "Check Point": "Check the discharge line connection to service line",
        "Procedure": "Check whether the compressor discharge line connected as per recommendation",
        "Root Cause": "1) Condesate water entered into the compressor during idle condition through MOS ADV 2) Compressor discharge is not connected as per recommendation",
        "Solution": "1) Ensure the compressor outlet pipe connected by ''inverted U'' with service line 2) Compressor to be isolated from the service line by closing the ball valve",
        "Key": "",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 683,
        "Language": "English",
        "Complaint Id": 74,
        "Sysmtom": "Water leakage from vent hole after unit shutdown",
        "Confirmation": "Water leakage observed after shutdown",
        "Check Point": "Check the blow down valve condition and its function while shut down for short time duration",
        "Procedure": "Dismantle the blow down valve and check condition of BDV kit",
        "Root Cause": "Blow down valve piston stuck/internal parts damaged",
        "Solution": "Replace the blow down valve assembly",
        "Key": "Blow down valve (BDV)",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 684,
        "Language": "English",
        "Complaint Id": 75,
        "Sysmtom": "Water level high in tank",
        "Confirmation": "No water from constant drain valve (Units with CDV drain system) No water from sump ADV drain (Units with sump ADV)",
        "Check Point": "Check for the blockage in the constant drain system strainer/orifice",
        "Procedure": "Remove the strainer/orifice and check for any dust contaminationor blockage",
        "Root Cause": "Foreign particle/Dust/Impurities entry in the water",
        "Solution": "1)Clean/Replace the strainer and orifice assembly 2)Flush the water system and replace new water completely",
        "Key": "Strainer",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 685,
        "Language": "English",
        "Complaint Id": 75,
        "Sysmtom": "Water level high in tank",
        "Confirmation": "No water from constant drain valve (Units with CDV drain system) No water from sump ADV drain (Units with sump ADV)",
        "Check Point": "Check the sump Auto drain valve (ADV) condition/function",
        "Procedure": "Remove and check the function of ADV or blockage",
        "Root Cause": "1) Solenoid valve failed internally 2) Foreign particle/Dust/Impurities entry in the water",
        "Solution": "Replace the sump ADV",
        "Key": "Auto drain valve ADV Solenoid valve",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 686,
        "Language": "English",
        "Complaint Id": 75,
        "Sysmtom": "Water level high in tank",
        "Confirmation": "No water from constant drain valve (Units with CDV drain system) No water from sump ADV drain (Units with sump ADV)",
        "Check Point": "Check the water level sensor function",
        "Procedure": "Remove and check the water level sensor float condition and its function",
        "Root Cause": "Water level sensor failure",
        "Solution": "Replace the water level sensor",
        "Key": "Water level sensor",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 687,
        "Language": "English",
        "Complaint Id": 76,
        "Sysmtom": "High differential pressure water filter alarm",
        "Confirmation": "Differential pressure is higher than the set pressure",
        "Check Point": "Check if the warning goes OFF when reset button is pressed during running",
        "Procedure": "Check the controller display",
        "Root Cause": "1) Controller set value disturbed 2) DP Pressure switch malfunction",
        "Solution": "1) Press the reset button in controller and monitor 2) Check and correct the set value in the switch and set differential pressure of 1.5 bar/ 20Psi 3) Change the pressure switch and set the value as per recommendation",
        "Key": "Pressure switch",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 688,
        "Language": "English",
        "Complaint Id": 76,
        "Sysmtom": "High differential pressure water filter alarm",
        "Confirmation": "Differential pressure is higher than the set pressure",
        "Check Point": "Is the differential pressure setting value disturbed",
        "Procedure": "Check the Water filter differential pressure set value in DP switch",
        "Root Cause": "1) Controller set value disturbed 2) DP Pressure switch malfunction",
        "Solution": "1)Press the reset button in controller and monitor 2) Check and correct the set value in the switch and set differential pressure of 1.5 bar/ 20Psi 3) Change the pressure switch and set the value as per recommendation",
        "Key": "Water filter differential pressure switch",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 689,
        "Language": "English",
        "Complaint Id": 76,
        "Sysmtom": "High differential pressure water filter alarm",
        "Confirmation": "Differential pressure is higher than the set pressure",
        "Check Point": "Is the water filter element choked",
        "Procedure": "Dismantle water filter element from assembly and check for any dust partical accumulation",
        "Root Cause": "1) Water filter element choked/Clogged with dust 2) Maintenance schedule not followed 3) Water quality is poor",
        "Solution": "1) Clean and replace the water filter element 2) Physical inspection for any sediments in the water at site 3) Check the water quality from lab 4) Flush the water system and replace new water completely",
        "Key": "Water filter element",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 690,
        "Language": "English",
        "Complaint Id": 77,
        "Sysmtom": "Water carryover",
        "Confirmation": "Water carry over observed in discharge line/Air receiver/Down stream filter and customer utility side.",
        "Check Point": "Check water level tube (Units with Constant drain valve-CDV)",
        "Procedure": "Check if the water level is above level tube during running",
        "Root Cause": "Low water level in water Separator tank",
        "Solution": "Top-up and maintain the water above the water level tube",
        "Key": "Water separator tank",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 691,
        "Language": "English",
        "Complaint Id": 77,
        "Sysmtom": "Water carryover",
        "Confirmation": "Water carry over observed in discharge line/Air receiver/Down stream filter and customer utility side.",
        "Check Point": "Check water level tube (Units with sump Auto drain valve-ADV)",
        "Procedure": "Check if the water level is half of level tube during running",
        "Root Cause": "Low water level in water Separator tank",
        "Solution": "Top-up and maintain the water half of water level tube",
        "Key": "Water separator tank",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 692,
        "Language": "English",
        "Complaint Id": 77,
        "Sysmtom": "Water carryover",
        "Confirmation": "Water carry over observed in discharge line/Air receiver/Down stream filter and customer utility side.",
        "Check Point": "Check water carryover at discharge line air receiver downstream filters and customer utility point",
        "Procedure": "Phycially check downstream accessories drain points and utility usage points for excess water condensate",
        "Root Cause": "1) High water level in the tank due to Constant drain valve (CDV) line chocked 2) Damaged water separator element 3) After cooler MOS choked",
        "Solution": "1) Check CDV strainer and orifice for any blockage Clean or replace as required 2) Replace the water separator element 3) Clean or replace the MOS auto drain valve 4) Top-up and maintain the water above the water level tube",
        "Key": "Constant drain valve (CDV)",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 693,
        "Language": "English",
        "Complaint Id": 77,
        "Sysmtom": "Water carryover",
        "Confirmation": "Water carry over observed in discharge line/Air receiver/Down stream filter and customer utility side.",
        "Check Point": "Check for high discharge air water temperature",
        "Procedure": "1)Check for any warning / trip in controller fault history 2)Check the fan motor current and fan motor body temperature 3)Check the air flow (hot air from the cooler out)",
        "Root Cause": "1) High room temperature due to poor ventilation 2) Restriction in the cooler exhaust duct (customer scope) 3) Restriction or hot air back flow due to cooler chock",
        "Solution": "1)If the compressor room temperature above the specified level contact ELGi 2)Verify the exhaust duct design or provision for exhaust fan for improving air flow 3)Clean the cooler with compressed air such that the air passes from inside to out",
        "Key": "",
        "is_active": 0
    },
    {
        "Group": "AB",
        "Solution Id": 694,
        "Language": "English",
        "Complaint Id": 77,
        "Sysmtom": "Water carryover",
        "Confirmation": "Water carry over observed in discharge line/Air receiver/Down stream filter and customer utility side.",
        "Check Point": "Check RH (Relative Humidity) level at customer site",
        "Procedure": "RH level at local site condition",
        "Root Cause": "High RH level at site",
        "Solution": "Contact ELGI for further details",
        "Key": "",
        "is_active": 0
    }
    ]   
    )

# Save the DataFrame to a temporary CSV file
temp_csv_path = tempfile.mktemp(suffix=".csv")
df.to_csv(temp_csv_path, index=False)

# Create the CSV agent using Ollama and the temporary CSV file
agent = create_csv_agent(llm, temp_csv_path, verbose=True)
df.head()
# Out:
#   Group  Solution Id Language  Complaint Id  \
# 0    AB          679  English            73
# 1    AB          680  English            74
# 2    AB          681  English            74
# 3    AB          682  English            74
# 4    AB          683  English            74
#
#                                             Sysmtom  \
# 0     Water leakage from vent holes (While running)
# 1  Water leakage from vent hole after unit shutdown
# 2  Water leakage from vent hole after unit shutdown
# 3  Water leakage from vent hole after unit shutdown
# 4  Water leakage from vent hole after unit shutdown
#
#                                         Confirmation  \
# 0  Continuous or intermittent water leakage durin...
# 1              Water leakage observed after shutdown
# 2              Water leakage observed after shutdown
# 3              Water leakage observed after shutdown
# 4              Water leakage observed after shutdown
#
#                                          Check Point  \
# 0  Is the water coming out from airend side vent ...
# 1  Check the Discharge check valve condition and ...
# 2  Check the Water stop valve condition and its f...
# 3  Check the discharge line connection to service...
# 4  Check the blow down valve condition and its fu...
#
#                                            Procedure  \
# 0  Check physically for the water leakage from ai...
# 1  1)Switch off the machine in normal stop mode a...
# 2  Dismantle the Water stop valve from the system...
# 3  Check whether the compressor discharge line co...
# 4  Dismantle the blow down valve and check condit...
#
#                                           Root Cause  \
# 0  1)Seal air pressure is low 2)Seal air pressure...
# 1  Discharge check valve Spring broken or Imprope...
# 2  1)Malfunctioning of solenoid coil 2)Diaphragm ...
# 3  1) Condesate water entered into the compressor...
# 4  Blow down valve piston stuck/internal parts da...
#
#                                             Solution  \
# 0  1)Increase the seal air pressure by checking g...
# 1         Replace the discharge check valve assembly
# 2  1 & 2) Replace the Water stop valve assembly 3...
# 3  1) Ensure the compressor outlet pipe connected...
# 4               Replace the blow down valve assembly
#
#                            Key  is_active
# 0        Seal air pressure low          0
# 1  Discharge check valve (DCV)          0
# 2             Water stop valve          0
# 3                                       0
# 4        Blow down valve (BDV)          0

# %%
agent
# Out:
# AgentExecutor(verbose=True, agent=ZeroShotAgent(llm_chain=LLMChain(prompt=PromptTemplate(input_variables=['agent_scratchpad', 'input'], partial_variables={'df_head': "|    | Group   |   Solution Id | Language   |   Complaint Id | Sysmtom                                          | Confirmation                                            | Check Point                                                                                  | Procedure                                                                                                                                                                                            | Root Cause                                                                                                                                                           | Solution                                                                                                                                                                                                                                                                                                                                                                                                       | Key                         |   is_active |\n|---:|:--------|--------------:|:-----------|---------------:|:-------------------------------------------------|:--------------------------------------------------------|:---------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------------------------|------------:|\n|  0 | AB      |           679 | English    |             73 | Water leakage from vent holes (While running)    | Continuous or intermittent water leakage during running | Is the water coming out from airend side vent holes                                          | Check physically for the water leakage from airend discharge vent holes                                                                                                                              | 1)Seal air pressure is low 2)Seal air pressure ball valve kept in close position 3)Seal air pressure MOS filter element choked 4)Defect in the discharge check valve | 1)Increase the seal air pressure by checking gauge in manifold (Units without Seal air pressure sensor) Increase the seal air pressure by checking the controller display (Units with Seal air pressure sensor) 2)Check and open the ball valve partially and set seal air pressure 3)Replace the seal air pressure MOS filter element or MOS assembly 4)Replace the DCV assembly and maintain the water level | Seal air pressure low       |           0 |\n|  1 | AB      |           680 | English    |             74 | Water leakage from vent hole after unit shutdown | Water leakage observed after shutdown                   | Check the Discharge check valve condition and its function                                   | 1)Switch off the machine in normal stop mode and observe water throw from airend vent holes 2)Dismantle discharge check valve from the system and visually check the condition of spring and plunger | Discharge check valve Spring broken or Improper seating of plunger                                                                 ...
# 0     AB          679  English            73
# 1     AB          680  English            74
# 2     AB          681  English            74
# 3     AB          682  English            74
# 4     AB          683  English            74
# 5     AB          684  English            75
# 6     AB          685  English            75
# 7     AB          686  English            75
# 8     AB          687  English            76
# 9     AB          688  English            76
# 10    AB          689  English            76
# 11    AB          690  English            77
# 12    AB          691  English            77
# 13    AB          692  English            77
# 14    AB          693  English            77
# 15    AB          694  English            77
#
#                                              Sysmtom  \
# 0      Water leakage from vent holes (While running)
# 1   Water leakage from vent hole after unit shutdown
# 2   Water leakage from vent hole after unit shutdown
# 3   Water leakage from vent hole after unit shutdown
# 4   Water leakage from vent hole after unit shutdown
# 5                           Water level high in tank
# 6                           Water level high in tank
# 7                           Water level high in tank
# 8      High differential pressure water filter alarm
# 9      High differential pressure water filter alarm
# 10     High differential pressure water filter alarm
# 11                                   Water carryover
# 12                                   Water carryover
# 13                                   Water carryover
# 14                                   Water carryover
# 15                                   Water carryover
#
#                                          Confirmation  \
# 0   Continuous or intermittent water leakage durin...
# 1               Water leakage observed after shutdown
# 2               Water leakage observed after shutdown
# 3               Water leakage observed after shutdown
# 4               Water leakage observed after shutdown
# 5   No water from constant drain valve (Units with...
# 6   No water from constant drain valve (Units with...
# 7   No water from constant drain valve (Units with...
# 8   Differential pressure is higher than the set p...
# 9   Differential pressure is higher than the set p...
# 10  Differential pressure is higher than the set p...
# 11  Water carry over observed in discharge line/Ai...
# 12  Water carry over observed in discharge line/Ai...
# 13  Water carry over observed in discharge line/Ai...
# 14  Water carry over observed in discharge line/Ai...
# 15  Water carry over observed in discharge line/Ai...
#
#                                           Check Point  \
# 0   Is the water coming out from airend side vent ...
# 1   Check the Discharge check valve condition and ...
# 2   Check the Water stop valve condition and its f...
# 3   Check the discharge line connection to service...
# 4   Check the blow down valve condition and its fu...
# 5   Check for the blockage in the constant drain s...
# 6   Check the sump Auto drain valve (ADV) conditio...
# 7               Check the water level sensor function
# 8   Check if the warning goes OFF when reset butto...
# 9   Is the differential pressure setting value dis...
# 10                 Is the water filter element choked
# 11  Check water level tube (Units with Constant dr...
# 12  Check water level tube (Units with sump Auto d...
# 13  Check water carryover at discharge line air re...
# 14     Check for high discharge air water temperature
# 15  Check RH (Relative Humidity) level at customer...
#
#                                             Procedure  \
# 0   Check physically for the water leakage from ai...
# 1   1)Switch off the machine in normal stop mode a...
# 2   Dismantle the Water stop valve from the system...
# 3   Check whether the compressor discharge line co...
# 4   Dismantle the blow down valve and check condit...
# 5   Remove the strainer/orifice and check for any ...
# 6    Remove and check the function of ADV or blockage
# 7   Remove and check the water level sensor float ...
# 8                        Check the controller display
# 9   Check the Water filter differential pressure s...
# 10  Dismantle water filter element from assembly a...
# 11  Check if the water level is above level tube d...
# 12  Check if the water level is half of level tube...
# 13  Phycially check downstream accessories drain p...
# 14  1)Check for any warning / trip in controller f...
# 15                   RH level at local site condition
#
#                                            Root Cause  \
# 0   1)Seal air pressure is low 2)Seal air pressure...
# 1   Discharge check valve Spring broken or Imprope...
# 2   1)Malfunctioning of solenoid coil 2)Diaphragm ...
# 3   1) Condesate water entered into the compressor...
# 4   Blow down valve piston stuck/internal parts da...
# 5   Foreign particle/Dust/Impurities entry in the ...
# 6   1) Solenoid valve failed internally 2) Foreign...
# 7                          Water level sensor failure
# 8   1) Controller set value disturbed 2) DP Pressu...
# 9   1) Controller set value disturbed 2) DP Pressu...
# 10  1) Water filter element choked/Clogged with du...
# 11            Low water level in water Separator tank
# 12            Low water level in water Separator tank
# 13  1) High water level in the tank due to Constan...
# 14  1) High room temperature due to poor ventilati...
# 15                              High RH level at site
#
#                                              Solution  \
# 0   1)Increase the seal air pressure by checking g...
# 1          Replace the discharge check valve assembly
# 2   1 & 2) Replace the Water stop valve assembly 3...
# 3   1) Ensure the compressor outlet pipe connected...
# 4                Replace the blow down valve assembly
# 5   1)Clean/Replace the strainer and orifice assem...
# 6                                Replace the sump ADV
# 7                      Replace the water level sensor
# 8   1) Press the reset button in controller and mo...
# 9   1)Press the reset button in controller and mon...
# 10  1) Clean and replace the water filter element ...
# 11  Top-up and maintain the water above the water ...
# 12  Top-up and maintain the water half of water le...
# 13  1) Check CDV strainer and orifice for any bloc...
# 14  1)If the compressor room temperature above the...
# 15                   Contact ELGI for further details
#
#                                           Key  is_active
# 0                       Seal air pressure low          0
# 1                 Discharge check valve (DCV)          0
# 2                            Water stop valve          0
# 3                                         NaN          0
# 4                       Blow down valve (BDV)          0
# 5                                    Strainer          0
# 6         Auto drain valve ADV Solenoid valve          0
# 7                          Water level sensor          0
# 8                             Pressure switch          0
# 9   Water filter differential pressure switch          0
# 10                       Water filter element          0
# 11                       Water separator tank          0
# 12                       Water separator tank          0
# 13                 Constant drain valve (CDV)          0
# 14                                        NaN          0
# 15                                        NaN          0  })])

# %%
agent.agent.llm_chain.prompt.template
# Out:
# '\nYou are working with a pandas dataframe in Python. The name of the dataframe is `df`.\nYou should use the tools below to answer the question posed of you:\n\npython_repl_ast: A Python shell. Use this to execute python commands. Input should be a valid python command. When using this tool, sometimes output is abbreviated - make sure it does not look abbreviated before using it in your answer.\n\nUse the following format:\n\nQuestion: the input question you must answer\nThought: you should always think about what to do\nAction: the action to take, should be one of [python_repl_ast]\nAction Input: the input to the action\nObservation: the result of the action\n... (this Thought/Action/Action Input/Observation can repeat N times)\nThought: I now know the final answer\nFinal Answer: the final answer to the original input question\n\n\nThis is the result of `print(df.head())`:\n{df_head}\n\nBegin!\nQuestion: {input}\n{agent_scratchpad}'

# %%
agent.run(" I have a symtom of water leakage from vent holes while running what is corresponding ```checkpoint```\
     answer the question from feeded data")
# Out:
# > Entering new AgentExecutor chain...
# To answer the question, you need to use the following steps:
#
# - Identify the symptom of water leakage from vent holes while running in the feeded data. This is given by the row with Solution Id = 679 and Complaint Id = 73.
# - Find the corresponding checkpoint answer for this symptom by looking at the column labeled Check Point. The value in this column is: Continuous or intermittent water leakage during running. Is the water coming out from airend side vent holes.
# - This means that the root cause of the problem could be any of the four possible checkpoints listed after the question. You need to investigate each one and see if they match the symptom.
# - The final answer is the checkpoint that matches the symptom most closely, or a combination of them if there is no single answer.
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\agents\agent.py:1066, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1065     # Call the LLM to see what to do.
# -> 1066     output = self.agent.plan(
#    1067         intermediate_steps,
#    1068         callbacks=run_manager.get_child() if run_manager else None,
#    1069         **inputs,
#    1070     )
#    1071 except OutputParserException as e:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\agents\agent.py:636, in Agent.plan(self, intermediate_steps, callbacks, **kwargs)
#     635 full_output = self.llm_chain.predict(callbacks=callbacks, **full_inputs)
# --> 636 return self.output_parser.parse(full_output)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\agents\mrkl\output_parser.py:63, in MRKLOutputParser.parse(self, text)
#      62 if not re.search(r"Action\s*\d*\s*:[\s]*(.*?)", text, re.DOTALL):
# ---> 63     raise OutputParserException(
#      64         f"Could not parse LLM output: `{text}`",
#      65         observation=MISSING_ACTION_AFTER_THOUGHT_ERROR_MESSAGE,
#      66         llm_output=text,
#      67         send_to_llm=True,
#      68     )
#      69 elif not re.search(
#      70     r"[\s]*Action\s*\d*\s*Input\s*\d*\s*:[\s]*(.*)", text, re.DOTALL
#      71 ):
#
# OutputParserException: Could not parse LLM output: `To answer the question, you need to use the following steps:
#
# - Identify the symptom of water leakage from vent holes while running in the feeded data. This is given by the row with Solution Id = 679 and Complaint Id = 73.
# - Find the corresponding checkpoint answer for this symptom by looking at the column labeled Check Point. The value in this column is: Continuous or intermittent water leakage during running. Is the water coming out from airend side vent holes.
# - This means that the root cause of the problem could be any of the four possible checkpoints listed after the question. You need to investigate each one and see if they match the symptom.
# - The final answer is the checkpoint that matches the symptom most closely, or a combination of them if there is no single answer.`
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 agent.run(" I have a symtom of water leakage from vent holes while running what is corresponding ```checkpoint```\
#       2      answer the question from feeded data")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:507, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     505     if len(args) != 1:
#     506         raise ValueError("`run` supports only one positional argument.")
# --> 507     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508         _output_key
#     509     ]
#     511 if kwargs and not args:
#     512     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     513         _output_key
#     514     ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:312, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
# --> 312     raise e
#     313 run_manager.on_chain_end(outputs)
#     314 final_outputs: Dict[str, Any] = self.prep_outputs(
#     315     inputs, outputs, return_only_outputs
#     316 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:306, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     299 run_manager = callback_manager.on_chain_start(
#     300     dumpd(self),
#     301     inputs,
#     302     name=run_name,
#     303 )
#     304 try:
#     305     outputs = (
# --> 306         self._call(inputs, run_manager=run_manager)
#     307         if new_arg_supported
#     308         else self._call(inputs)
#     309     )
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\agents\agent.py:1312, in AgentExecutor._call(self, inputs, run_manager)
#    1310 # We now enter the agent loop (until it returns something).
#    1311 while self._should_continue(iterations, time_elapsed):
# -> 1312     next_step_output = self._take_next_step(
#    1313         name_to_tool_map,
#    1314         color_mapping,
#    1315         inputs,
#    1316         intermediate_steps,
#    1317         run_manager=run_manager,
#    1318     )
#    1319     if isinstance(next_step_output, AgentFinish):
#    1320         return self._return(
#    1321             next_step_output, intermediate_steps, run_manager=run_manager
#    1322         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\agents\agent.py:1038, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1029 def _take_next_step(
#    1030     self,
#    1031     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1035     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1036 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1037     return self._consume_next_step(
# -> 1038         [
#    1039             a
#    1040             for a in self._iter_next_step(
#    1041                 name_to_tool_map,
#    1042                 color_mapping,
#    1043                 inputs,
#    1044                 intermediate_steps,
#    1045                 run_manager,
#    1046             )
#    1047         ]
#    1048     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\agents\agent.py:1038, in <listcomp>(.0)
#    1029 def _take_next_step(
#    1030     self,
#    1031     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1035     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1036 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1037     return self._consume_next_step(
# -> 1038         [
#    1039             a
#    1040             for a in self._iter_next_step(
#    1041                 name_to_tool_map,
#    1042                 color_mapping,
#    1043                 inputs,
#    1044                 intermediate_steps,
#    1045                 run_manager,
#    1046             )
#    1047         ]
#    1048     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\agents\agent.py:1077, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1075     raise_error = False
#    1076 if raise_error:
# -> 1077     raise ValueError(
#    1078         "An output parsing error occurred. "
#    1079         "In order to pass this error back to the agent and have it try "
#    1080         "again, pass `handle_parsing_errors=True` to the AgentExecutor. "
#    1081         f"This is the error: {str(e)}"
#    1082     )
#    1083 text = str(e)
#    1084 if isinstance(self.handle_parsing_errors, bool):
#
# ValueError: An output parsing error occurred. In order to pass this error back to the agent and have it try again, pass `handle_parsing_errors=True` to the AgentExecutor. This is the error: Could not parse LLM output: `To answer the question, you need to use the following steps:
#
# - Identify the symptom of water leakage from vent holes while running in the feeded data. This is given by the row with Solution Id = 679 and Complaint Id = 73.
# - Find the corresponding checkpoint answer for this symptom by looking at the column labeled Check Point. The value in this column is: Continuous or intermittent water leakage during running. Is the water coming out from airend side vent holes.
# - This means that the root cause of the problem could be any of the four possible checkpoints listed after the question. You need to investigate each one and see if they match the symptom.
# - The final answer is the checkpoint that matches the symptom most closely, or a combination of them if there is no single answer.`

# %% [markdown]
# Trying with different csv approach

# %%
from langchain.document_loaders import CSVLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.chains import RetrievalQA
from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
from llama_index import VectorStoreIndex
from llama_index.storage import in_memory
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[38], line 2
#       1 from llama_index import VectorStoreIndex
# ----> 2 from llama_index.storage import in_memory
#
# ImportError: cannot import name 'in_memory' from 'llama_index.storage' (C:\Users\intern_dx23\AppData\Roaming\Python\Python311\site-packages\llama_index\storage\__init__.py)

# %%
loader=CSVLoader(file_path='D:\problems.csv')

# %%
llm = Ollama(base_url='http://172.17.226.116:11434',
model="orca-mini:3b",temperature=0.8,top_k=40,top_p=0.9,repeat_penalty=1.1,repeat_last_n=64,tfs_z=1,
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()]))

# %%
index_creator=VectorstoreIndexCreator()
docsearch= index_creator.from_loaders([loader])
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 index_creator=VectorstoreIndexCreator()
#       2 docsearch= index_creator.from_loaders([loader])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\main.py:339, in BaseModel.__init__(__pydantic_self__, **data)
#     333 """
#     334 Create a new model by parsing and validating input data from keyword arguments.
#     335
#     336 Raises ValidationError if the input data cannot be parsed to form a valid model.
#     337 """
#     338 # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
#     341     raise validation_error
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\main.py:1066, in validate_model(model, input_data, cls)
#    1063     errors.append(ErrorWrapper(MissingError(), loc=field.alias))
#    1064     continue
# -> 1066 value = field.get_default()
#    1068 if not config.validate_all and not field.validate_always:
#    1069     values[name] = value
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\fields.py:439, in ModelField.get_default(self)
#     438 def get_default(self) -> Any:
# --> 439     return smart_deepcopy(self.default) if self.default_factory is None else self.default_factory()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for OpenAIEmbeddings
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass  `openai_api_key` as a named parameter. (type=value_error)
